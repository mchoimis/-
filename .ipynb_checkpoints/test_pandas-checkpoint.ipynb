# %%
# Python version check
import sys
# !{sys.executable} --version

# %%
# version check
import sklearn
print('이 노트북에 사용된 scikit-learn 버전: {}.'.format(sklearn.__version__))

# %%
import sqlite3 as sq

# %%
from sql import *
from sql.aggregate import *
from sql.conditionals import *

# %%
import numpy as np
import random
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Step 0. Glossary
#     - trx07
#     - trx08
#     - trx09
#     - upjong
#     - cus

# %% [markdown]
# Step 1. Data Extraction

# %%
# make sample

num_txn = 1000000 # 1/10 of real data 
num_CLNN = 40000 # 1/10 of real data

array01 = np.random.randint(0, num_CLNN, size=(num_txn, 1) ) # CLNN
array02 = np.random.randint(180701, 180731, size=(num_txn, 1)) # TS_D # 승인날짜
array03 = np.random.randint(0, 100, size=(num_txn, 1)) # FINAL_CD # 업종코드

# %%
array04a = np.random.randn(num_txn, 1) # SAA # 승인금액
array04 = array04^2

# %%
array05 = np.random.randint(0, 424, size=(num_txn, 1)) # MCT_ADM_GDS_APB_CD # 서울 행정동 코드

# %%
array06a = np.random.randint(1, 2, size=(round(num_txn*5/7), 1)) # DOF_TF # 평일 or 휴일
array06b = np.random.randint(0, 1, size=(round(num_txn*2/7), 1)) # DOF_TF # 평일 or 휴일
array06 = np.append(array06a, array06b, axis=0)
# array06ab.shape[0] # faction 했기 때문에 최종 number of row 확인

# %%
random.shuffle(array06ab)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-662ea63463d3> in <module>()
# ----> 1 random.shuffle(array06ab)
#
# ~\Anaconda3\lib\random.py in shuffle(self, x, random)
#     270         if random is None:
#     271             randbelow = self._randbelow
# --> 272             for i in reversed(range(1, len(x))):
#     273                 # pick an element in x[:i+1] with which to exchange x[i]
#     274                 j = randbelow(i+1)
#
# TypeError: len() of unsized object

# %%
array07 = np.random.randint(0, 6, size=(num_txn, 1)) # DAW_CCD # 요일코드 # array06과 맞추기 어려워서

# %%
array08 = np.random.randint(0, 100000, size=(num_txn, 1)) # MCT_N # 가맹점 번호

# %%
array09 = np.random.randint(1, 240000, size=(num_txn, 1)) # TIME # 24h 시간

# %%
df = pd.DataFrame( np.column_stack([array01, array02, array03, array04, array05, array06, array07, array08, array09])
                  , columns = ['CLNN', 'TS_D', 'FINAL_CD', 'SAA', 'MCT_ADM_GDS_APB_CD', 'DOF_TF', 'DAW_CCD', 'MCT_N', 'TIME'])

df.head()
# Out:
#     CLNN    TS_D  FINAL_CD  SAA  MCT_ADM_GDS_APB_CD  DOF_TF  DAW_CCD  MCT_N  \
# 0  14737  180717        38  875                 292       1        3  98333
# 1  33245  180729        41  782                 303       1        2  57276
# 2  19315  180724        23  732                 344       1        0  35089
# 3    716  180706        67   74                 237       1        4  29533
# 4  31275  180718        98  775                 394       1        5  64408
#
#      TIME
# 0  224004
# 1  171223
# 2  227028
# 3  234778
# 4  100012

# %% [markdown]
# ### GroupBy 객체 만들기

# %%
groupedByCLNN = df.groupby('CLNN')

# %%
groupedByCLNN.describe()['SAA'].head() # 계산시 오래걸림
# Out:
#       count        mean         std   min     25%    50%     75%    max
# CLNN
# 0      16.0  499.625000  327.491450  28.0  275.75  380.0  820.25  979.0
# 1      31.0  419.612903  260.388258  28.0  210.50  346.0  575.00  987.0
# 2      29.0  470.551724  315.077041   8.0  183.00  494.0  695.00  984.0
# 3      27.0  500.703704  275.368957  26.0  337.00  487.0  658.50  987.0
# 4      18.0  481.277778  287.149849  82.0  236.00  494.0  635.75  994.0

# %%
groupedByCLNN.sum()['SAA'].head()

# %%
# 2개 기준으로 Group By 하기
gb = df.groupby(['CLNN', 'MCT_ADM_GDS_APB_CD']) # 고객별 & 행정동별
gb2 = gb.sum()['SAA'] # 금액 합
gb2
# Out:
# CLNN   MCT_ADM_GDS_APB_CD
# 0      22                     914
#        44                     928
#        64                     188
#        86                     372
#        89                      28
#        114                    665
#        144                     80
#        146                    512
#        218                   1354
#        344                    283
#        378                    254
#        381                    979
#        395                    789
#        402                    353
#        423                    295
# 1      0                      206
#        3                      233
#        39                     584
#        42                     357
#        53                     560
#        74                     336
#        109                    566
#        138                    256
#        144                    647
#        156                    379
#        166                    766
#        172                    217
#        179                    185
#        214                    346
#        218                     83
#                              ...
# 39999  111                     26
#        115                    840
#        116                    376
#        131                     67
#        144                    803
#        157                    161
#        175                    848
#        183                   1249
#        194                    948
#        198                    796
#        211                    966
#        223                     76
#        228                    531
#        236                    787
#        257                    237
#        264                    744
#        274                    436
#        277                    509
#        279                    657
#        331                    988
#        337                    379
#        341                    700
#        349                     19
#        370                    428
#        376                    110
#        378                    830
#        382                    200
#        392                    270
#        393                     52
#        397                    722
# Name: SAA, Length: 971312, dtype: int32

# %%
# 2개 기준으로 Group By 하기
gb3 = df.groupby(['CLNN', 'MCT_ADM_GDS_APB_CD']).sum()['SAA'] # 고객별 & 행정동별 합 chaining
gb3
# Out:
# CLNN   MCT_ADM_GDS_APB_CD
# 0      22                     914
#        44                     928
#        64                     188
#        86                     372
#        89                      28
#        114                    665
#        144                     80
#        146                    512
#        218                   1354
#        344                    283
#        378                    254
#        381                    979
#        395                    789
#        402                    353
#        423                    295
# 1      0                      206
#        3                      233
#        39                     584
#        42                     357
#        53                     560
#        74                     336
#        109                    566
#        138                    256
#        144                    647
#        156                    379
#        166                    766
#        172                    217
#        179                    185
#        214                    346
#        218                     83
#                              ...
# 39999  111                     26
#        115                    840
#        116                    376
#        131                     67
#        144                    803
#        157                    161
#        175                    848
#        183                   1249
#        194                    948
#        198                    796
#        211                    966
#        223                     76
#        228                    531
#        236                    787
#        257                    237
#        264                    744
#        274                    436
#        277                    509
#        279                    657
#        331                    988
#        337                    379
#        341                    700
#        349                     19
#        370                    428
#        376                    110
#        378                    830
#        382                    200
#        392                    270
#        393                     52
#        397                    722
# Name: SAA, Length: 971312, dtype: int32

# %%
df.sort_values(['MCT_ADM_GDS_APB_CD', 'SAA'], ascending=False).groupby('CLNN').head()
# Out:
#          CLNN    TS_D  FINAL_CD  SAA  MCT_ADM_GDS_APB_CD  DOF_TF  DAW_CCD  \
# 36061   28830  180723        14  999                 423       1        5
# 352984   3143  180721        29  999                 423       1        1
# 489033  12160  180717        88  999                 423       1        5
# 503383   7262  180701        72  999                 423       1        3
# 864531   9185  180717        14  999                 423       0        0
# 367647  35615  180722        93  998                 423       1        5
# 602991  33468  180725        79  998                 423       1        2
# 863896   8331  180724        65  998                 423       0        0
# 42367   18305  180715        62  996                 423       1        2
# 706865  14157  180704        71  996                 423       1        1
# 125405  37345   70677
# 529037  40842  175555
# 457731  57176  141213
# 975303  10724   30394
# 400382   7548   40306
# 734969  38379  220016
# 15419   26464   19990
# 545323  41796  230311
# 199891   1141  193145
# 34577   33164   75518
# 506864  18052  138620
# 885322  49822   90454
# 519636  75808  148268
# 923901  41572  151283
# 690640  53793  238307
# 230869  84640   43247
# 53335   48704  146828
# 891825  14200   12014
# 404799  61223   86322
#
# [200000 rows x 9 columns]

# %%
df.groupby(['job','source']).agg({'count':sum})

# %% [markdown]
# ### GroupBy 객체를 sorting 하기

# %%
gb2.apply(lambda _df: _df.sort_values(by=['SAA']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-9542de945a98> in <module>()
# ----> 1 gb2.apply(lambda _df: _df.sort_values(by=['SAA']))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-58-9542de945a98> in <lambda>(_df)
# ----> 1 gb2.apply(lambda _df: _df.sort_values(by=['SAA']))
#
# AttributeError: 'int' object has no attribute 'sort_values'

# %%
df.pivot('MCT_ADM_GDS_APB_CD', 'FINAL_CD', 'CLNN')

# %%
df.sort_values(by=['MCT_ADM_GDS_APB_CD', 'TIME'], ascending=True).head()

# %% [markdown]
# ### 조건에 맞는 일부 원소만 추출하기

# %% [markdown]
# ### 문자열을 숫자로 type 바꾸기

# %% [markdown]
# ### 시간정보를 파싱하기

# %%
# upjong

num_upjong = 2786049
upjong = pd.DataFrame(np.random.randint(0, 100, size=(num_upjong, 3)))
upjong.columns = ['MCT_N', 'FINAL_CD', 'FINAL_CD_NM']
upjong.head()

# %%
grouped = upjong.groupby('MCT_N')

# %%
grouped.head()

# %%
grouped.count().head()

# %%
grouped.describe()['SAA'].head()

# %%
# file read in memory 
# takes a long time so beware session failure
trx07 = pd.read_csv('')

# %%
# file read in memory 
# takes a long time so beware session failure
trx08 = pd.read_csv('')

# %%
# file read in memory 
# takes a long time so beware session failure
trx09 = pd.read_csv('')

# %%
# check if data is succesfully loaded in memory
# count rows

# %%
# check data

# %% [markdown]
# Step 2. Data Wrangling

# %%
# count trx, group by dong

# Make GroupBy object
groupByDong = trx07.groupby('dong')

# %%
groupedByDong.count()
groupedByDong.sum()

# %% [markdown]
# 만약 특정 변수에 대해서만 그룹별 요약/집계를 하고 싶다면 해당 변수를 indexing해주면 되며, 한개 변수에 대해서만 GroupBy 집계를 하면 반환되는 결과는 Series가 됩니다. 한개 변수에 대해 GroupBy 집계해서 나온 Series를 DataFrame으로 만들고 싶으면 pd.DataFrame() 를 사용해서 집계 결과를 DataFrame으로 변환해주면 됩니다.

# %%
groupedByDong.sum()['amount'] # Series

pd.DataFrame(groupedByDong.sum()['amount']) # DataFrame

# %%
groupedByDong.describe()['amount']

# %% [markdown]
# 필요로 하는 집계함수가 pandas GroupBy methods에 없는 경우 사용자 정의 함수를 정의해서 집계에 사용할 수 있습니다. IQR(Inter-Quartile Range, Q3 - Q1) 를 사용자 정의 함수로 정의하고, 이를 grouped.aggregate() 혹은 grouped.agg() 의 괄호 안에 넣어서 그룹 별로 IQR를 계산해보겠습니다.

# %%
def iqr_func(x):

    q3, q1 = np.percentile(x, [75, 25])

    iqr = q3 - q1

    return iqr

# %%
groupedByDong.agg(iqr_func) # groupedByDong.aggregate(iqr_func) 도 같은 결과
